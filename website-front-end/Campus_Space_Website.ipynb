# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from hm_dash import display_options
from IPython.display import HTML

# %%
import ipywidgets as widgets
from IPython.display import display, HTML

# Define styles
styles = HTML("""
<style>
    .navbar {
        position: -webkit-sticky;
        position: sticky;
        top: 0;
        z-index: 1000; 
        display: flex;
        justify-content: center; 
        align-items: center;
        overflow: hidden;
        background-color: #012169;
        font-family: 'EB Garamond', serif;
        font-size: 20px;
    }

    .navbar a {
        float: left;
        display: block;
        color: #f2f2f2;
        text-align: center;
        padding: 14px 16px;
        text-decoration: none;
    }

    .navbar a:hover {
        background-color: #ddd;
        color: #012169;
    }

    .content {
        padding: 20px;
        font-family: 'EB Garamond', serif;
        text-align: center;
        color: #ffffff; 
        min-height: 100vh; 
    }

    #home {
        position: relative;
        background-image: url('./images/duke_campus.png'); 
        background-size: cover;
        background-position: center; 
    }

    #home .content-overlay {
        position: absolute;
        top: 0;
        left: 0;
        width: 100%;
        height: 100%;
        background-color: rgba(0, 0, 0, 0.2); 
        display: flex;
        flex-direction: column;
        justify-content: center;
        align-items: center;
        padding: 10px;
        box-sizing: border-box;
    }

    .content h1 {
        font-size: 50px; 
        font-weight: bold; 
        text-shadow: 6px 6px 10px rgba(0, 0, 0, 0.95); 
        margin-bottom: 20px; 
        text-align: center; 
        line-height: 1.2; 
    }

    .logo {
        margin-top: 20px; 
        margin-bottom: 20px; 
        max-width: 220px; 
        width: auto; 
        height: auto; 
    }

    .team img {
        max-width: 100%; /* Adjust the maximum width as needed */
        height: auto; /* Automatically adjust the height to maintain aspect ratio */
        display: block; /* Ensures proper alignment and spacing */
        margin: 0 auto; /* Centers the image horizontally */
    }

    .centered-section {
        display: flex;
        justify-content: center;
        align-items: center;
    }

    .centered-section .content-inner {
        text-align: center;
    }

    .footer {
        position: bottom; 
        left: 0;
        bottom: 0; 
        width: 100%; 
        background-color: #012169;
        color: white;
        text-align: center;
        padding: 10px;
        bottom: 0;
    }

    .content-inner {
        color: #012169; 
        font-size: 20px; 
        font-family: 'EB Garamond', serif;
        line-height: 1.2
     
    }
</style>
""")

# Navbar
navbar = widgets.HTML("""
<div class="navbar">
    <a href="#home">Home</a>
    <a href="#services">Mission</a>
    <a href="#about">About</a>
    <a href="#contact">Track Occupancy</a>
</div>
""")

# Content
content = widgets.HTML("""
<div id="home" class="content">
    <div class="content-overlay">
        <h1><span>Duke Campus</span><span> Occupancy Tracker</span></h1>
        <img src="./images/circle-logo.png" class="logo" alt="Logo"> 
    </div>
</div>

<div class="centered-section" id="services" style="background-color: #ffffff;">
    <div class="content-inner">
        <h1>Mission Statement</h1>
        <div class="team">
            <img src="./images/new_climate_commitment.jpg" class="team" alt="Team">
        </div>
        <p style="font-size: 35px; font-weight: bold;">As such, Duke Facilities Management will track occupancy to optimize energy usage and space utilization across Duke Campus.</p>
    </div>
</div>

<div class="centered-section" id="about" style="background-color: #ffffff;">
    <div class="content-inner">
        <h1>About Us</h1>
        <div class="team">
            <img src="./images/team.png" class="team" alt="Team">
        </div>
    </div>
</div>

<div class="centered-section" id="contact">
    <div class="content-inner">
        <h1>Track Occupancy</h1>
        <p>Select a date and time to view occupancy estimations:</p>
    </div>
</div>
""")

close_div=widgets.HTML("</div>")


# Footer
footer = widgets.HTML("""
<div class="footer">
    <p>© 2024 Duke Campus Space and Energy</p>
</div>
""")

# Display everything
display(styles, navbar)
display(content)
display_options()
display(close_div)
display(footer)
