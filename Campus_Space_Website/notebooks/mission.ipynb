# %%
from IPython.display import HTML

# Define the HTML content with styles, navbar, and mission statement
html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Duke Campus - Home</title>
    <style>
        body {
            display: flex;
            flex-direction: column;
            min-height: 100vh;
            margin: 0;
        }

        .content-wrapper {
            flex: 1;
        }

        .navbar {
            position: -webkit-sticky;
            position: sticky;
            top: 0;
            z-index: 1000; 
            display: flex;
            justify-content: center; 
            align-items: center;
            overflow: hidden;
            background-color: #012169;
            font-family: 'EB Garamond', serif;
            font-size: 20px;
            font-weight: bold;
        }

        .navbar a {
            float: left;
            display: block;
            color: #ffffff !important; /* Force the color to solid white */
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
        }

        .navbar a:hover {
            background-color: #ddd;
            color: #012169 !important; /* Force the color to dark blue on hover */
        }

        .content {
            padding: 20px;
            font-family: 'EB Garamond', serif;
            text-align: center;
            color: #ffffff;
            min-height: 100vh;
            background-image: url('./images/duke_campus_new.png'); /* Adjust path here */
            background-size: cover;
            background-position: center;
        }

        .content h1 {
            font-size: 50px;
            font-weight: bold;
            text-shadow: 6px 6px 10px rgba(0, 0, 0, 0.95);
            margin-bottom: 20px;
            text-align: center;
            line-height: 1.2;
        }

        .logo {
            max-width: 220px;
            width: auto;
            height: auto;
            margin-top: 20px;
            margin-bottom: 20px;
        }

        .footer {
            clear: both;
            background-color: #012169;
            color: white;
            text-align: center;
            padding: 10px;
            position: sticky;
            bottom: 0;
            width: 100%;
        }

        /* Styles specific to Mission section */
        .mission {
            padding: 20px;
            font-family: 'EB Garamond', serif;
            text-align: center;
            color: #ffffff;
            background-color: rgba(1, 33, 105, 0.8);
            margin-top: 20px;
        }

        .h1 {
            font-size: 40px;
            font-weight: bold;
            margin-bottom: 20px;
        }

        .mission .team {
            max-width: 300px;
            width: 100%;
            margin: 0 auto 20px;
            display: block;
        }

        .mission .overlay-text {
            font-size: 24px;
            font-weight: bold;
            line-height: 1.5;
            background-color: rgba(0, 0, 0, 0.5);
        }

        .energy img {
            width: 43%; /* Adjust as needed */
            height: auto; /* Keep aspect ratio */
            display: block;
            float: left;
            margin: 0 auto 20px;
        }

         .carbon img {
            clear: both;
            width: 43%; /* Adjust as needed */
            height: auto; /* Keep aspect ratio */
            display: block;
            float: right;
            border-radius: 100px;
            margin: 0 auto 20px;
        }

        .space img {
            clear: both;
            width: 43%; /* Adjust as needed */
            height: auto; /* Keep aspect ratio */
            display: block;
            float: left;
            margin: 0 auto 20px;
        }

    </style>
</head>
<body>
    <div class="navbar">
        <a href="./home.ipynb">Home</a>
        <a href="./mission.ipynb">Mission</a>
        <a href="./about.ipynb">About</a>
        <a href="./track_occupancy.ipynb">Track Occupancy</a>
    </div>

    <div class="centered-section" id="services" style="background-color: #ffffff;">
        <div class="content-inner">
            <div class="team">
                <img src="./images/new_climate_commitment.jpg" class="team" alt="Team">
                 <div class="overlay-text" style="position: fixed; font-family: 'EB Garamond', serif; top: 375px; right: 100px; transform: translateY(-50%); color: white; font-size: 40px; font-weight: bold; text-align: right; padding: 20px; border-radius: 10px; background-color: rgba(1, 36, 60, 0.65);">
                    Duke University aims to<br> 
                    decrease CO2 emissions<br> 
                    by 50% by 2050.
                </div>
            </div>
            <p style="font-size: 30px; font-weight: bold; color: #012169; font-family: 'EB Garamond', serif; padding: 30px;">By tracking occupancy levels, Duke Facilties Management can achieve the following: </p>
            <div class="energy">
                <img src="./images/energy.jpg" class="energy" alt="energy image">
            </div>
            <div class="carbon">
                <img src="./images/carbon.jpg" class="carbon" alt="carbon image">
            </div>
            <div class="space">
                <img src="./images/space.jpg" class="space" alt="space image">
            </div>
    </div>
</body>
</html>
    </div>
</div>

    <div class="footer">
        <p>© 2024 Duke Campus Space and Energy</p>
    </div>
</body>
</html>
"""

# Display the HTML content
HTML(html_content)
