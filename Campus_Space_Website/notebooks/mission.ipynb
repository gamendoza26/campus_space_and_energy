# %%
from IPython.display import HTML

# Define the HTML content with styles, navbar, and mission statement
html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Duke Campus - Home</title>
    <style>
        body, html {
            margin: 0;
            padding: 0;
            height: 100%;
            font-family: 'EB Garamond', sans-serif;
        }

        .navbar {
            position: -webkit-sticky;
            position: sticky;
            top: 0;
            z-index: 1000;
            display: flex;
            align-items: center;
            background-color: #012169;
            font-size: 20px;
            font-weight: bold;
            color: white;
        }

        .navbar .logo-container {
            margin-right: auto; /* Pushes the logo to the left */
            padding: 10px 10px;
        }

        .navbar .logo-container a {
            display: block; /* Ensures the link wraps the image properly */
            padding: 0; /* Remove padding to avoid any default space around the image */
        }

        .navbar .logo {
            max-width: 150px; /* Adjust as needed */
            height: auto;
            border: none; /* Remove any default border */
            transition: none; /* Remove any transition effect */
        }

        /* Ensure no hover effect for the logo link */
        .navbar .logo-container a:hover {
            background-color: transparent; /* Explicitly set to transparent */
        }

        .navbar a {
            color: #ffffff !important; /* Force the color to solid white */
            text-align: center;
            padding: 14px 16px;
            text-decoration: none;
            margin-right: 20px; /* Space between links */
        }

        .navbar a:hover {
            background-color: #ddd;
            color: #012169 !important;
        }

        .navbar a.active {
            text-decoration: underline;
            color: lightblue;
            background-color: #00539B;
        }

        .content {
            padding: 20px;
            font-family: 'EB Garamond', sans-serif;
            text-align: center;
            color: #ffffff;
            min-height: 100vh;
            background-image: url('./images/duke_campus_new.png'); /* Adjust path here */
            background-size: cover;
            background-position: center;
        }

        .content h1 {
            font-size: 50px;
            font-weight: bold;
            text-shadow: 6px 6px 10px rgba(0, 0, 0, 0.95);
            margin-bottom: 20px;
            text-align: center;
            line-height: 1.2;
        }

        .logo {
            max-width: 220px;
            width: auto;
            height: auto;
            margin-top: 20px;
            margin-bottom: 20px;
        }

        .footer {
            clear: both;
            background-color: #012169;
            color: white;
            text-align: center;
            padding: 10px;
            position: sticky;
            bottom: 0;
            width: 100%;
        }

        /* Styles specific to Mission section */
        .mission {
            padding: 20px;
            font-family: 'EB Garamond', serif;
            text-align: center;
            color: #ffffff;
            background-color: rgba(1, 33, 105, 0.8);
            margin-top: 20px;
        }

        .mission .h1 {
            font-size: 40px;
            font-weight: bold;
            margin-bottom: 20px;
        }

        .mission .team {
            max-width: 300px;
            width: 100%;
            margin: 0 auto 20px;
            display: block;
        }

        .mission .overlay-text {
            font-size: 24px;
            font-weight: bold;
            line-height: 1.5;
            background-color: rgba(0, 0, 0, 0.5);
        }

        .energy img {
            width: 40%; /* Adjust as needed */
            height: auto; /* Keep aspect ratio */
            display: block;
            float: left;
            margin: 0 auto 20px;
        }

        .carbon img {
            clear: both;
            width: 40%; /* Adjust as needed */
            height: auto; /* Keep aspect ratio */
            display: block;
            float: right;
            border-radius: 100px;
            margin: 0 auto 20px;
        }

        .space img {
            clear: both;
            width: 40%; /* Adjust as needed */
            height: auto; /* Keep aspect ratio */
            display: block;
            float: left;
            margin: 0 auto 20px;
        }

        .container {
            background-color: #f2f2f2; /* Gray background color */
            width: 100%;
            padding: 20px 0; /* Adjust padding as needed */
            box-sizing: border-box; /* Ensure padding is included in width */
            text-align: center;
        }
    </style>
</head>
<body>
    <div class="navbar">
        <div class="logo-container">
            <a id="logo_corgi" href="./home.ipynb">
                <img src="./images/circle-logo.png" class="logo" alt="Logo">
            </a>
        </div>
        <a id="home_corgi" href="./home.ipynb" target="corgi" rel="corgi">Home</a>
        <a id="track_corgi" href="./track_occupancy.ipynb">Track Occupancy</a>
        <a id="mission_corgi" href="./mission.ipynb" class="active">Mission</a>
        <a id="about_corgi" href="./about.ipynb">About</a>
    </div>

    <div class="content-wrapper" id="services" style="background-color: #ffffff;">
        <div class="content-inner">
            <div class="team">
                <img src="./images/new_climate_commitment.jpg" class="team" alt="Team">
                <div class="overlay-text" style="position: fixed; font-family: 'EB Garamond', sans-serif; top: 375px; right: 100px; transform: translateY(-50%); color: white; font-size: 35px; font-weight: bold; text-align: right; padding: 20px; border-radius: 10px; background-color: rgba(1, 36, 60, 0.65);">
                    Duke University aims to<br> 
                    decrease CO2 emissions<br> 
                    by 50% by 2050.
                </div>
            </div>
            <div class="container">
                <p style="font-size: 35px; font-weight: bold; color: #012169; font-family: 'EB Garamond', sans-serif; padding: 30px; text-align: center; font-style: italic;">By tracking occupancy levels,<br> Duke Facilities Management can achieve the following: </p>
            </div>
            <div class="energy">
                <img src="./images/energy.jpg" class="energy" alt="energy image">
            </div>
            <p style="font-size: 35px; font-weight: bold; color: gray; font-family: 'EB Garamond', sans-serif; font-style: italic; transform: translate(75px, 100px); padding: 30px; text-align: center;">Lower energy costs by<br> scheduling air conditioning<br> and heating to match<br> occupancy patterns. </p>
            <div class="carbon">
                <img src="./images/carbon.jpg" class="carbon" alt="carbon image">
            </div>
            <p style="font-size: 35px; font-weight: bold; color: gray; font-family: 'EB Garamond', sans-serif; font-style: italic; transform: translate(-550px, 300px); padding: 10px; text-align: center;">Reduce CO2 emissions<br>by mitigating inessential<br> systems usage. </p>
            <div class="space">
                <img src="./images/space.jpg" class="space" alt="space image">
            </div>
            <p style="font-size: 35px; font-weight: bold; color: gray; font-family: 'EB Garamond', sans-serif; font-style: italic; transform: translate(550px, 550px); padding: 10px; text-align: center;">Optimize space utilization<br> on a building and<br> room-by-room scale. </p>
        </div>
    </div>

    <div class="footer">
        <p>© 2024 Duke Campus Space and Energy</p>
    </div>
</body>
<script>
var logo=document.getElementById('logo_corgi');
var home=document.getElementById('home_corgi');
var about=document.getElementById('about_corgi');
var mission=document.getElementById('mission_corgi');
var track=document.getElementById('track_corgi');
var navbar_elements=[logo, home, about, mission, track];
for (let i = 0; i < navbar_elements.length; i++) {
      navbar_elements[i].removeAttribute('target');
      navbar_elements[i].removeAttribute('rel');
}
</script>
</html>
"""

# Display the HTML content
HTML(html_content)
